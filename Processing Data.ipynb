# %%
#importing important packages

import numpy as np
import pandas as pd
import pickle

# %%
# Reading in raw data that has not been processed at all
# DO NOT RUN THIS IF YOU'VE ALREADY STARTED PROCESSING

data = pd.read_csv("C:/Users/Andre/Documents/DBL/Reaching Understanding Study/merged_data_allsubs_wtext.csv", encoding_errors= 'replace')

# %%
# Global variables zone:
#     Tweak these to change little details about how the program runs

FILE_SAVE_LOCATION: str = "C:/Users/Andre/Documents/DBL/Reaching Understanding Study/Conversations/"      # Each post will saved into this folder as an individual .csv named after its post id.
CMT_CHAIN_LEN: int = 4                                        # Filter for comment chains of the length specified here.
IMPORTANT_COLUMNS: list = ["cmt_id","submission_title","text","submission_link_id","created_utc","author","author_id","cmt_link_id","cmt_parent_id"] # Keeps only columns noted here, the other ones are not useful

# %%
# Function definition zone
# Just run this

def remove_t(element):
  """Remove the 't3_' 't2_' and 't1_' from all cells that have them as a prefix to the data we want to use. - andre.chiquit.ooo"""
  if type(element) == str:
    if element[2] == "_":
      return (element[3:])
    else: 
      return (element)
  else:
    return (element)


def pull_post(data: pd.DataFrame, post_id: str) -> pd.DataFrame:
  """Creates a DataFrame out of a specific post_id."""
  return data[data['submission_link_id']==post_id]


def find_top_level_comments(data: pd.DataFrame) -> pd.DataFrame:
  """Finds all the top level comments."""
  return  data[data["cmt_parent_id"] == data["submission_link_id"]]


def find_children(data: pd.DataFrame, parent_id: str) -> pd.DataFrame:
  """Finds all the child comments from a certain comment."""
  return data[data["cmt_parent_id"]==parent_id]


def assemble_children(data: pd.DataFrame, top_comment_id: str, parent_df: pd.DataFrame) -> pd.DataFrame:
  """Creates a data frame for all responses to top level comment."""
  children = find_children(data, top_comment_id)
  parent_df = parent_df.append(children, ignore_index=True)
  for child in children["cmt_id"]:
    parent_df=assemble_children(data, child, parent_df)
  return parent_df


def multi_data_frame(data: pd.DataFrame) -> pd.DataFrame:
  """Function to turn data frame into a 3d data frame by parent comment. This one is kinda cool, but it makes the data wayyyy harder to work with."""
  top_cmts=find_top_level_comments(data)
  top_comment_names=top_cmts["cmt_id"]
  top_comment_names.name="top_comment_id"
  all_dfs=[]
  for top_cmt in top_cmts["cmt_id"]:
    starting_df=data[data["cmt_id"]==top_cmt]
    comment_replies=assemble_children(data,top_cmt,starting_df)
    all_dfs.append(comment_replies)
  final_dfs = pd.concat(all_dfs, axis=0, keys=top_comment_names, ignore_index=False)
  return final_dfs


def is_not_top(comment: pd.DataFrame) -> bool:
  """Checks whether a comment is a top level comment."""
  if (comment["cmt_parent_id"].equals(comment["submission_link_id"])):
    return False
  else:
    return True


def grab_parent_comment(data: pd.DataFrame, current_comment: pd.DataFrame) -> pd.DataFrame:
  """grabs parent comment and returns it."""
  # print(f"Variable: data            - the entire dataframe for the post in question           : {data}")
  # print(f"Variable: current_comment - a dataframe with a single row that's the active comment : {current_comment}")
  if (is_not_top(current_comment)):
    return data[data["cmt_id"]==current_comment["cmt_parent_id"].item()]
  else:
    return


def get_parent_cmt_ids(data: pd.DataFrame, current_comment: pd.DataFrame, comment_chain) -> list:
  """function to add comment id to chain."""
  parent = grab_parent_comment(data, current_comment)
  
  if parent is not None:
    # print(f"Variable: data            - the entire dataframe for the post in question (I think...) : {data}")
    # print(f"Variable: current_comment - a dataframe with a single row that's the active comment    : {current_comment}")
    # print(f"Variable: comment_chain   - a list with comment IDs in it                              : {comment_chain}") # Debug??
    # print(f"Variable: parent          - a dataframe resulting from running grab_parent_comment     : {parent}")
    comment_chain.append(parent["cmt_id"].item())
    for par in parent["cmt_id"]:
      get_parent_cmt_ids(data,data[data["cmt_id"]==par],comment_chain)
  return comment_chain


def get_parent_author_ids(data: pd.DataFrame, current_comment: pd.DataFrame, author_chain) -> list:
  """function to add author id to chain."""
  parent = grab_parent_comment(data, current_comment)
  
  if parent is not None:
    author_chain.append(parent["author_id"].item())
    for par in parent["cmt_id"]:
      get_parent_author_ids(data,data[data["cmt_id"]==par],author_chain)
  return author_chain


def add_cmt_aut_chains(data: pd.DataFrame) -> pd.DataFrame:
  """Adds comment and author chain to regular data frame."""
  final_data=data
  final_data["cmt_chain"]=[[] for _ in range(final_data.shape[0])]
  final_data["author_chain"]=[[] for _ in range(final_data.shape[0])]
  for comment in data["cmt_id"]:
      this_comment=data[data["cmt_id"]==comment]
      
      #initialize comment and author chain variables
      cmt_chain=[]
      aut_chain=[]
      cmt_chain.append(this_comment["cmt_id"].item())
      aut_chain.append(this_comment["author_id"].item())

      #create chains
      comment_chain=get_parent_cmt_ids(data,this_comment,cmt_chain)
      author_chain=get_parent_author_ids(data,this_comment,aut_chain)

      #add chains to data
      final_data.at[final_data[final_data["cmt_id"]==this_comment["cmt_id"].item()].index.item(),"cmt_chain"]=comment_chain
      final_data.at[final_data[final_data["cmt_id"]==this_comment["cmt_id"].item()].index.item(),"author_chain"]=author_chain
  return final_data


def remove_orphans(data: pd.DataFrame) -> pd.DataFrame:
  """Remove comments that have no parent."""
  truthValues=[]
  # print(f"Data currently has {len(data)} comments")
  for par in data["cmt_parent_id"]:
    if data["cmt_id"].str.contains(par).any() | data["submission_link_id"].str.contains(par).any():
      truthValues.append(True)
    else:
      truthValues.append(False)
  data = data[truthValues]
  # print(truthValues)
  # print(f"After removing orphans, data now has {len(data)} comments")
  if False in truthValues:
    data = remove_orphans(data)
  return data


def add_unique_authors(data: pd.DataFrame) -> pd.DataFrame:
  """Add unique authors column."""
  data=data.reset_index(drop = True)
  for i in range(len(data.index)):
    data.at[i,"unique_authors"]=list(dict.fromkeys(data.at[i,"author_chain"]))
  return data


def add_cmt_aut_chain_strings(data: pd.DataFrame) -> pd.DataFrame:
  """Adds author and comment chains as string."""
  final_df=data
  for comment in data["cmt_id"]:
    this_comment=data[data["cmt_id"]==comment]
    final_df.at[final_df[final_df["cmt_id"]==this_comment["cmt_id"].item()].index.item(),"cmt_chain_string"]="_".join(this_comment["cmt_chain"].item())
    final_df.at[final_df[final_df["cmt_id"]==this_comment["cmt_id"].item()].index.item(),"author_chain_string"]="_".join(this_comment["author_chain"].item())
  return final_df

def troubleshooting_add_cmt_aut_chain_strings(data: pd.DataFrame) -> pd.DataFrame:
  """Adds author and comment chains as string."""
  final_df=data
  counter: int = 0
  for comment in data["cmt_id"]:
    print(f"Currently processing [{counter}/{len(data.index)}]")
    this_comment=data[data["cmt_id"]==comment]
    final_df.at[final_df[final_df["cmt_id"]==this_comment["cmt_id"].item()].index.item(),"cmt_chain_string"]="_".join(this_comment["cmt_chain"].item())
    final_df.at[final_df[final_df["cmt_id"]==this_comment["cmt_id"].item()].index.item(),"author_chain_string"]="_".join(this_comment["author_chain"].item())
    counter += 1
  return final_df


def is_not_found_later(data: pd.DataFrame, comment_chain_str: str):
  """Determine if string of comments is in a later comment."""
  is_not_found=True
  temp_data=data[data["cmt_chain_string"] != comment_chain_str]
  for cmt_chain_str in temp_data["cmt_chain_string"]:
    if comment_chain_str in cmt_chain_str:
      is_not_found=False
  return is_not_found


def remove_duped_comment_chains(data: pd.DataFrame) -> pd.DataFrame:
  """Remove comment chains that are found later."""
  truthValues=[]
  for cmt_chain in data["cmt_chain_string"]:
    if is_not_found_later(data,cmt_chain):
      truthValues.append(True)
    else:
      truthValues.append(False)
  return data[truthValues]


def pull_all_conversations(data: pd.DataFrame) -> pd.DataFrame:
  """Pull all conversations that are at least 2 unique authors."""
  # The output sometimes ends up with conversations that are just two unique authors, but more often it seems to have many more than two. I'm going to leave this code as is
  #     and write a new function to filter the number of authors down to two 
  final_convos=data[data["unique_authors"].map(len)==2]

  messy_convos=data[data["unique_authors"].map(len)>2]
  for mess in messy_convos["cmt_id"]:
    author_chain=messy_convos[messy_convos["cmt_id"]==mess]["author_chain"].item()
    unique_set=messy_convos[messy_convos["cmt_id"]==mess]["unique_authors"].item()[0:2] #this grabs the first two authors which is all we care about
    i=0
    while(author_chain[i] in unique_set):
      i=i+1
    new_comment_line=messy_convos[messy_convos["cmt_id"]==mess]
    new_comment_line.at[new_comment_line.index.item(),"cmt_chain"]=new_comment_line["cmt_chain"].item()[0:i]
    new_comment_line.at[new_comment_line.index.item(),"author_chain"]=new_comment_line["author_chain"].item()[0:i]
    final_convos=pd.concat([final_convos,new_comment_line],ignore_index=True)

  final_convos=add_cmt_aut_chain_strings(final_convos)
  
  final_convos=remove_duped_comment_chains(final_convos)
  
  return final_convos


def add_cmt_chain_len(data: pd.DataFrame) -> pd.DataFrame:
  """Adds a column denoting the length of each comment chain. - andre.chiquit.ooo"""
  data=data.reset_index(drop = True)
  for i in range(len(data.index)):
    x = len(data.at[i,"cmt_chain"])
    data.at[i,"cmt_chain_len"] = x
  return data

def unique_cells(data: pd.DataFrame) -> list:
  """Returns a list of every unique value in a dataframe. If you want to use this on one column, which you probably do, make sure to call it on one column. Enables us to avoid using groupby. - andre.chiquit.ooo"""
  authors: list = []
  x: int = 0
  for element in data:
    if (x % 250000) == 0:
      if x < 1000000:
        print(f".{str(x)[:2]} million rows out of ~{str(len(data.index))[:1]}.{str(len(data.index))[1:2]} million total rows processed.")
      else:
        print(f"{str(x)[:1]}.{str(x)[1:3]} million rows out of ~{str(len(data.index))[:1]}.{str(len(data.index))[1:2]} million total rows processed.")
    x += 1
    if element not in authors:
      authors.append(element)
  return (authors)

def add_convo_metadata(data: pd.DataFrame, convos:pd.DataFrame) -> pd.DataFrame:
  """Takes a dataframe of comments and adds columns to each comment to include metadata on the conversations to which they belong, taken from a second dataframe. - andre.chiquit.ooo"""
  x: int = 0
  z: int = 0
  data.reset_index(inplace = True, drop = True)
  convos.reset_index(inplace = True, drop = True)
  for i in range(len(convos.index)):
    x = 0
    while x < len(convos.at[i, "cmt_chain"]):
      for comment in convos.at[i, "cmt_chain"]:
        z = 0
        while z < len(data.index):
          if data.at[z, "cmt_id"] == comment:
            data.at[z, "convo_id"] = convos.at[i, "cmt_chain_string"]
            data.at[z, "unique_authors"] = convos.at[i, "unique_authors"]
            data.at[z, "cmt_chain_len"] = convos.at[i, "cmt_chain_len"]
            z += len(data.index)
          z += 1
      x += 1
  return data

def cmt_chain_len_filter(data: pd.DataFrame, convo_len: int) -> pd.DataFrame:
  """Filters a dataframe for comment chains of a certain length. - andre.chiquit.ooo"""
  mask = []
  for i in range(len(data.index)):
    if data.at[i, "cmt_chain_len"] < convo_len:
      mask.append(False)
    else:
      mask.append(True)
  data = data[mask]
  return data

def dyadic_convo_filter(data: pd.DataFrame) -> pd.DataFrame:
  """Filters a dataframe for only those conversations that have two authors. - andre.chiquit.ooo"""
  mask = []
  for i in range(len(data.index)):
    if len(data.at[i, "unique_authors"]) == 2:
      mask.append(True)
    else:
      mask.append(False)
  data = data[mask]
  return data

def filter_out_comments(data: pd.DataFrame) -> pd.DataFrame:
  """Filters out any comments that aren't related to the identified conversations and organizes them based on conversation and creation time. - andre.chiquit.ooo"""
  mask = []
  data.reset_index(inplace = True, drop = True)
  for i in range(len(data.index)):
    if type(data.at[i, "convo_id"]) == str:
      mask.append(True)
    else:
      mask.append(False)
  data = data[mask]
  data = data.sort_values(by =['convo_id', 'created_utc'])
  return data

def processing_for_coding(data: pd.DataFrame) -> None:
  """Function to use on a dataset to convert it to a dataset with comment chain conversations grouped, ready to be coded. Does not make use of groupby. Intended to be run start to finish on an entire dataset, may take a loooong time."""
  print("Filtering out for important columns only.")
  data = data[IMPORTANT_COLUMNS]
  data = data.dropna()
  print("Removing 't1_', 't2_', and 't3_' from the cells in which they appear")
  data[['author_id','cmt_link_id','cmt_parent_id']]=data[['author_id','cmt_link_id','cmt_parent_id']].applymap(remove_t)
  print("Making a list of all the post IDs included in the data")
  post_ids = unique_cells(data["submission_link_id"])
  post_index: int = 1
  posts = len(post_ids)
  print("Time to process each post... Hang on!")
  for post in post_ids:
    if post_index % 100 == 0:
      print(f"Currently processing post_id {post} ({post_index}/{posts}). {posts - post_index} posts left . . .")
    data1 = pull_post(data, post)
    if len(data1.index) > 0:
      data1 = remove_orphans(data1)
      if len(data1.index) > 0:
        data1 = add_cmt_aut_chains(data1)
        data1 = add_unique_authors(data1)
        data1 = add_cmt_aut_chain_strings(data1)
        data_convos = pull_all_conversations(data1)
        data_convos = add_cmt_chain_len(data_convos)
        data_convos = dyadic_convo_filter(data_convos)
        data_convos = cmt_chain_len_filter(data_convos, CMT_CHAIN_LEN)
        if len(data_convos.index) > 0:
          data1 = add_convo_metadata(data1, data_convos)
          data1.reset_index(drop = True, inplace = True)
          data1 = filter_out_comments(data1)
          data1.to_csv(FILE_SAVE_LOCATION + f"{post}_conversations.csv")
    post_index += 1
  return None

def processing_for_coding_after_list(data: pd.DataFrame, post_ids: list) -> None:
  """Uses the list of post id method rather than groupby. Intended to pick up where you left off after cleaning the data and generating a list of all post_ids included in the dataset."""
  post_index: int = 1
  posts = len(post_ids)
  print("Time to process each post... Hang on!")
  for post in post_ids:
    if (post_index % 100) == 0:
      print(f"Currently processing post_id {post} ({post_index}/{posts}). {posts - post_index} posts left . . .")
    data1 = pull_post(data, post)
    if len(data1.index) > 0:
      data1 = remove_orphans(data1)
      if len(data1.index) > 0:
        data1 = add_cmt_aut_chains(data1)
        data1 = add_unique_authors(data1)
        data1 = add_cmt_aut_chain_strings(data1)
        data_convos = pull_all_conversations(data1)
        data_convos = add_cmt_chain_len(data_convos)
        data_convos = dyadic_convo_filter(data_convos)
        data_convos = cmt_chain_len_filter(data_convos, CMT_CHAIN_LEN)
        if len(data_convos.index) > 0:
          data1 = add_convo_metadata(data1, data_convos)
          data1.reset_index(drop = True, inplace = True)
          data1 = filter_out_comments(data1)
          data1.to_csv(FILE_SAVE_LOCATION + f"{post}_conversations.csv")
    post_index += 1
  return None

def processing_for_coding_troubleshooting(data: pd.DataFrame, post_id: str) -> None:
  """Identical to the function above, but for use with troubleshooting a specific post id."""
  data1 = pull_post(data, post_id)
  print(f"Currently processing post: {post_id}")
  if len(data1.index) > 0:
    print("Removing orphans!")
    data1 = remove_orphans(data1)
    if len(data1.index) > 0:
      print("Adding comment/author chains!")
      data1 = add_cmt_aut_chains(data1)
      print("Adding unique authors!")
      data1 = add_unique_authors(data1)
      print("Adding comment/author chain strings!")
      data1 = add_cmt_aut_chain_strings(data1)
      print("Pulling all conversations!")
      data_convos = pull_all_conversations(data1)
      print("Adding comment chain length!")
      data_convos = add_cmt_chain_len(data_convos)
      print("Filtering out non-dyadic conversations!")
      data_convos = dyadic_convo_filter(data_convos)
      print("Filtering for length of comment chain!")
      data_convos = cmt_chain_len_filter(data_convos, CMT_CHAIN_LEN)
      if len(data_convos.index) > 0:
        print("Adding conversation metadata!")
        data1 = add_convo_metadata(data1, data_convos)
        data1.reset_index(drop = True, inplace = True)
        data1 = filter_out_comments(data1)
        print("Saving the file!")
        data1.to_csv(FILE_SAVE_LOCATION + f"{post_id}_conversations.csv")
  print("Made it to the end!")
  return None

def processing_posts(data: pd.DataFrame) -> None:
  """Processes each post. Meant for use with groupby. WORK IN PROGRESS."""
  print("Made it all the way to processing_posts function!")
  print(data)
  data = remove_orphans(data)
  print("I guess it removed the orphans man")
  data = add_cmt_aut_chains(data)
  data = add_unique_authors(data)
  data = add_cmt_aut_chain_strings(data)
  data_convos = pull_all_conversations(data)
  data_convos = add_cmt_chain_len(data_convos)
  data_convos = dyadic_convo_filter(data_convos)
  data_convos = cmt_chain_len_filter(data_convos, CMT_CHAIN_LEN)
  if len(data_convos.index) > 0:
    data = add_convo_metadata(data, data_convos)
    data.reset_index(drop = True, inplace = True)
    data = filter_out_comments(data)
    data.to_csv(FILE_SAVE_LOCATION + f"{data.at[0, 'submission_link_id']}_conversations.csv")
  return None


def processing_for_coding_groupby(data: pd.DataFrame) -> None:
  """Processes Reddit comments and makes use of the groupby method. WORK IN PROGRESS."""
  print("Filtering out for important columns only.")
  data = data[IMPORTANT_COLUMNS]
  data = data.dropna()
  print("Removing 't1_', 't2_', and 't3_' from the cells in which they appear")
  data[['author_id','cmt_link_id','cmt_parent_id']]=data[['author_id','cmt_link_id','cmt_parent_id']].applymap(remove_t)
  groups = data.groupby(['submission_link_id'], sort = False)
  groups.transform(processing_posts)
  return None

# %% [markdown]
# The code below is trying to make groupby work

# %%
processing_for_coding_groupby(data)

# %% [markdown]
# The code below will work, but it will take a while. It would be more efficient to use groupby, which I was playing with creating a function to do that above.

# %%
# Filters out the data into important columns only
# Drops rows with any NA values
# Remove 't1_' etc prefixes
# Creates a list of all the post_ids in the dataset

print("Filtering out for important columns only.")
data = data[IMPORTANT_COLUMNS]
data = data.dropna()
print("Removing 't1_', 't2_', and 't3_' from the cells in which they appear")
data[['author_id','cmt_link_id','cmt_parent_id']]=data[['author_id','cmt_link_id','cmt_parent_id']].applymap(remove_t)
print("Making a list of all the post IDs included in the data")
post_ids = unique_cells(data["submission_link_id"])

# %%
# Saves the modified dataset and list of post_ids so that you don't have to run the lengthy code above again

data.to_csv("C:/Users/Andre/Documents/DBL/Reaching Understanding Study/no_t_data.csv")

with open("C:/Users/Andre/Documents/DBL/Reaching Understanding Study/post_id_list", "wb") as post_id_list:
    pickle.dump(post_ids, post_id_list)

# %%
# Running through all the data and cutting short the post_id list so that I can start where I left off last time. Hopefully this won't be necessary after debugging.

post_ids_progress = post_ids[14500:]

# %%
# Run this to load the pre-modified dataset and the post_id list

data = pd.read_csv("C:/Users/Andre/Documents/DBL/Reaching Understanding Study/no_t_data.csv", encoding_errors= 'replace')

with open("C:/Users/Andre/Documents/DBL/Reaching Understanding Study/post_id_list", "rb") as save_file:
    test_post_ids = pickle.load(save_file)
# Out:
# 113193

# %%
# Processing through the data. If you're picking up where you left off, make sure to modify the post_ids_progress assignment block two blocks up

processing_for_coding_after_list(data, post_ids_progress)
# Out:
# Time to process each post... Hang on!
# Currently processing post_id orogzi (50/98693). 98643 posts left . . .
# Currently processing post_id otdm51 (100/98693). 98593 posts left . . .
# Currently processing post_id oukx4a (150/98693). 98543 posts left . . .
# Currently processing post_id ovtr2i (200/98693). 98493 posts left . . .
# Currently processing post_id ox4ttb (250/98693). 98443 posts left . . .
# Currently processing post_id oymghx (300/98693). 98393 posts left . . .
# Currently processing post_id ozs30q (350/98693). 98343 posts left . . .
# Currently processing post_id p15k5e (400/98693). 98293 posts left . . .
# Currently processing post_id p2cmfx (450/98693). 98243 posts left . . .
# Currently processing post_id p3c97l (500/98693). 98193 posts left . . .
# Currently processing post_id p4g5du (550/98693). 98143 posts left . . .
# Currently processing post_id p63fah (600/98693). 98093 posts left . . .
# Currently processing post_id p760ao (650/98693). 98043 posts left . . .
# Currently processing post_id p8hytm (700/98693). 97993 posts left . . .
# Currently processing post_id pg0jv4 (750/98693). 97943 posts left . . .
# Currently processing post_id patedc (800/98693). 97893 posts left . . .
# Currently processing post_id pbl3u9 (850/98693). 97843 posts left . . .
# Currently processing post_id pc99l9 (900/98693). 97793 posts left . . .
# Currently processing post_id pcvckr (950/98693). 97743 posts left . . .
# Currently processing post_id pei1a0 (1000/98693). 97693 posts left . . .
# Currently processing post_id pfr8tx (1050/98693). 97643 posts left . . .
# Currently processing post_id pgj2rl (1100/98693). 97593 posts left . . .
# Currently processing post_id pi14xn (1150/98693). 97543 posts left . . .
# Currently processing post_id pk7fk2 (1200/98693). 97493 posts left . . .
# Currently processing post_id pl5td3 (1250/98693). 97443 posts left . . .
# Currently processing post_id pn0417 (1300/98693). 97393 posts left . . .
# Currently processing post_id po71ub (1350/98693). 97343 posts left . . .
# Currently processing post_id ppg2ev (1400/98693). 97293 posts left . . .
# Currently processing post_id pqfsh6 (1450/98693). 97243 posts left . . .
# Currently processing post_id pryd6h (1500/98693). 97193 posts left . . .
# Currently processing post_id fs7o8z (1550/98693). 97143 posts left . . .
# Currently processing post_id fs9aas (1600/98693). 97093 posts left . . .
# Currently processing post_id fsb5yl (1650/98693). 97043 posts left . . .
# Currently processing post_id fsd9v0 (1700/98693). 96993 posts left . . .
# Currently processing post_id fsfrow (1750/98693). 96943 posts left . . .
# Currently processing post_id fsi4fw (1800/98693). 96893 posts left . . .
# Currently processing post_id fskfst (1850/98693). 96843 posts left . . .
# Currently processing post_id fsnoho (1900/98693). 96793 posts left . . .
# Currently processing post_id fsq740 (1950/98693). 96743 posts left . . .
# Currently processing post_id fsssek (2000/98693). 96693 posts left . . .
# Currently processing post_id fsuqo5 (2050/98693). 96643 posts left . . .
# Currently processing post_id fswo39 (2100/98693). 96593 posts left . . .
# Currently processing post_id fsyw3a (2150/98693). 96543 posts left . . .
# Currently processing post_id ft10dw (2200/98693). 96493 posts left . . .
# Currently processing post_id ft3quw (2250/98693). 96443 posts left . . .
# Currently processing post_id ft7q7m (2300/98693). 96393 posts left . . .
# Currently processing post_id ftb4nh (2350/98693). 96343 posts left . . .
# Currently processing post_id ftdhi1 (2400/98693). 96293 posts left . . .
# Currently processing post_id ftfxl4 (2450/98693). 96243 posts left . . .
# Currently processing post_id fti2oy (2500/98693). 96193 posts left . . .
# Currently processing post_id ftk001 (2550/98693). 96143 posts left . . .
# Currently processing post_id ftm8yi (2600/98693). 96093 posts left . . .
# Currently processing post_id ftoz2r (2650/98693). 96043 posts left . . .
# Currently processing post_id ftrh02 (2700/98693). 95993 posts left . . .
# Currently processing post_id fttlsx (2750/98693). 95943 posts left . . .
# Currently processing post_id ftw48c (2800/98693). 95893 posts left . . .
# Currently processing post_id fty89t (2850/98693). 95843 posts left . . .
# Currently processing post_id fu143g (2900/98693). 95793 posts left . . .
# Currently processing post_id fu3od6 (2950/98693). 95743 posts left . . .
# Currently processing post_id fu5e0p (3000/98693). 95693 posts left . . .
# Currently processing post_id fu7eut (3050/98693). 95643 posts left . . .
# Currently processing post_id fu9l85 (3100/98693). 95593 posts left . . .
# Currently processing post_id fucsm7 (3150/98693). 95543 posts left . . .
# Currently processing post_id fug2to (3200/98693). 95493 posts left . . .
# Currently processing post_id fuk4ux (3250/98693). 95443 posts left . . .
# Currently processing post_id fummle (3300/98693). 95393 posts left . . .
# Currently processing post_id fuocw3 (3350/98693). 95343 posts left . . .
# Currently processing post_id fuqjjy (3400/98693). 95293 posts left . . .
# Currently processing post_id futtpx (3450/98693). 95243 posts left . . .
# Currently processing post_id fuvpgy (3500/98693). 95193 posts left . . .
# Currently processing post_id fuy1r8 (3550/98693). 95143 posts left . . .
# Currently processing post_id fv15m3 (3600/98693). 95093 posts left . . .
# Currently processing post_id fv4kss (3650/98693). 95043 posts left . . .
# Currently processing post_id fv75xg (3700/98693). 94993 posts left . . .
# Currently processing post_id fv9scw (3750/98693). 94943 posts left . . .
# Currently processing post_id fvbvox (3800/98693). 94893 posts left . . .
# Currently processing post_id fvdy6c (3850/98693). 94843 posts left . . .
# Currently processing post_id fvhaz9 (3900/98693). 94793 posts left . . .
# Currently processing post_id fvjt2m (3950/98693). 94743 posts left . . .
# Currently processing post_id fvlpgs (4000/98693). 94693 posts left . . .
# Currently processing post_id fvnx0d (4050/98693). 94643 posts left . . .
# Currently processing post_id fvptm8 (4100/98693). 94593 posts left . . .
# Currently processing post_id fvs8zj (4150/98693). 94543 posts left . . .
# Currently processing post_id fvuhew (4200/98693). 94493 posts left . . .
# Currently processing post_id fvw6wb (4250/98693). 94443 posts left . . .
# Currently processing post_id fvxw9u (4300/98693). 94393 posts left . . .
# Currently processing post_id fw0ex2 (4350/98693). 94343 posts left . . .
# Currently processing post_id fw37i3 (4400/98693). 94293 posts left . . .
# Currently processing post_id fw587g (4450/98693). 94243 posts left . . .
# Currently processing post_id fw7vm3 (4500/98693). 94193 posts left . . .
# Currently processing post_id fwbbew (4550/98693). 94143 posts left . . .
# Currently processing post_id fwe2qn (4600/98693). 94093 posts left . . .
# Currently processing post_id fwh6nc (4650/98693). 94043 posts left . . .
# Currently processing post_id fwj7q9 (4700/98693). 93993 posts left . . .
# Currently processing post_id fwly9g (4750/98693). 93943 posts left . . .
# Currently processing post_id fwpi1e (4800/98693). 93893 posts left . . .
# Currently processing post_id fwsu7c (4850/98693). 93843 posts left . . .
# Currently processing post_id fwvaco (4900/98693). 93793 posts left . . .
# Currently processing post_id fwy51w (4950/98693). 93743 posts left . . .
# Currently processing post_id fx0a24 (5000/98693). 93693 posts left . . .
# Currently processing post_id fx2ifx (5050/98693). 93643 posts left . . .
# Currently processing post_id fx4sa2 (5100/98693). 93593 posts left . . .
# Currently processing post_id fx753m (5150/98693). 93543 posts left . . .
# Currently processing post_id fxazd9 (5200/98693). 93493 posts left . . .
# Currently processing post_id fxdfj2 (5250/98693). 93443 posts left . . .
# Currently processing post_id fxiinn (5300/98693). 93393 posts left . . .
# Currently processing post_id fxll2x (5350/98693). 93343 posts left . . .
# Currently processing post_id fxohgt (5400/98693). 93293 posts left . . .
# Currently processing post_id fxqka6 (5450/98693). 93243 posts left . . .
# Currently processing post_id fxszyk (5500/98693). 93193 posts left . . .
# Currently processing post_id fxw0xb (5550/98693). 93143 posts left . . .
# Currently processing post_id fxzzjo (5600/98693). 93093 posts left . . .
# Currently processing post_id fy4cjo (5650/98693). 93043 posts left . . .
# Currently processing post_id fy7iyk (5700/98693). 92993 posts left . . .
# Currently processing post_id fycc4l (5750/98693). 92943 posts left . . .
# Currently processing post_id fyee0w (5800/98693). 92893 posts left . . .
# Currently processing post_id fygq9d (5850/98693). 92843 posts left . . .
# Currently processing post_id fylof5 (5900/98693). 92793 posts left . . .
# Currently processing post_id fyqfmp (5950/98693). 92743 posts left . . .
# Currently processing post_id fytu0o (6000/98693). 92693 posts left . . .
# Currently processing post_id fywyzs (6050/98693). 92643 posts left . . .
# Currently processing post_id fz1o8c (6100/98693). 92593 posts left . . .
# Currently processing post_id fz5zdi (6150/98693). 92543 posts left . . .
# Currently processing post_id fzc9ri (6200/98693). 92493 posts left . . .
# Currently processing post_id fzknjg (6250/98693). 92443 posts left . . .
# Currently processing post_id fzno89 (6300/98693). 92393 posts left . . .
# Currently processing post_id fzrgsx (6350/98693). 92343 posts left . . .
# Currently processing post_id fzuke2 (6400/98693). 92293 posts left . . .
# Currently processing post_id fzxu1w (6450/98693). 92243 posts left . . .
# Currently processing post_id g026jv (6500/98693). 92193 posts left . . .
# Currently processing post_id g06fou (6550/98693). 92143 posts left . . .
# Currently processing post_id g0aesk (6600/98693). 92093 posts left . . .
# Currently processing post_id g0d955 (6650/98693). 92043 posts left . . .
# Currently processing post_id g0g1zk (6700/98693). 91993 posts left . . .
# Currently processing post_id g0i6qt (6750/98693). 91943 posts left . . .
# Currently processing post_id g0lcdz (6800/98693). 91893 posts left . . .
# Currently processing post_id g0phrv (6850/98693). 91843 posts left . . .
# Currently processing post_id g0t3j1 (6900/98693). 91793 posts left . . .
# Currently processing post_id g0xa1h (6950/98693). 91743 posts left . . .
# Currently processing post_id g10f4a (7000/98693). 91693 posts left . . .
# Currently processing post_id g12kmi (7050/98693). 91643 posts left . . .
# Currently processing post_id g13zip (7100/98693). 91593 posts left . . .
# Currently processing post_id g16eon (7150/98693). 91543 posts left . . .
# Currently processing post_id g1az5d (7200/98693). 91493 posts left . . .
# Currently processing post_id g1emev (7250/98693). 91443 posts left . . .
# Currently processing post_id g1hy4z (7300/98693). 91393 posts left . . .
# Currently processing post_id g1kazg (7350/98693). 91343 posts left . . .
# Currently processing post_id g1mnsv (7400/98693). 91293 posts left . . .
# Currently processing post_id g1orv4 (7450/98693). 91243 posts left . . .
# Currently processing post_id g1q8ji (7500/98693). 91193 posts left . . .
# Currently processing post_id g1sh6m (7550/98693). 91143 posts left . . .
# Currently processing post_id g1vfe3 (7600/98693). 91093 posts left . . .
# Currently processing post_id g1ydt8 (7650/98693). 91043 posts left . . .
# Currently processing post_id g212pe (7700/98693). 90993 posts left . . .
# Currently processing post_id g24l1f (7750/98693). 90943 posts left . . .
# Currently processing post_id g26xqb (7800/98693). 90893 posts left . . .
# Currently processing post_id g29l21 (7850/98693). 90843 posts left . . .
# Currently processing post_id g2bn57 (7900/98693). 90793 posts left . . .
# Currently processing post_id g2d7o6 (7950/98693). 90743 posts left . . .
# Currently processing post_id g2epsd (8000/98693). 90693 posts left . . .
# Currently processing post_id g2hjma (8050/98693). 90643 posts left . . .
# Currently processing post_id g2jwm2 (8100/98693). 90593 posts left . . .
# Currently processing post_id g2mjk2 (8150/98693). 90543 posts left . . .
# Currently processing post_id g2q1ct (8200/98693). 90493 posts left . . .
# Currently processing post_id g2ssfl (8250/98693). 90443 posts left . . .
# Currently processing post_id g2uzad (8300/98693). 90393 posts left . . .
# Currently processing post_id g2xllp (8350/98693). 90343 posts left . . .
# Currently processing post_id g2zjpn (8400/98693). 90293 posts left . . .
# Currently processing post_id g31mno (8450/98693). 90243 posts left . . .
# Currently processing post_id g35d8n (8500/98693). 90193 posts left . . .
# Currently processing post_id g39kvy (8550/98693). 90143 posts left . . .
# Currently processing post_id g3e0gz (8600/98693). 90093 posts left . . .
# Currently processing post_id g3gu7t (8650/98693). 90043 posts left . . .
# Currently processing post_id g3jplf (8700/98693). 89993 posts left . . .
# Currently processing post_id g3m14j (8750/98693). 89943 posts left . . .
# Currently processing post_id g3pgsb (8800/98693). 89893 posts left . . .
# Currently processing post_id g3ugjt (8850/98693). 89843 posts left . . .
# Currently processing post_id g3yu37 (8900/98693). 89793 posts left . . .
# Currently processing post_id g426mc (8950/98693). 89743 posts left . . .
# Currently processing post_id g45nnw (9000/98693). 89693 posts left . . .
# Currently processing post_id g48xsw (9050/98693). 89643 posts left . . .
# Currently processing post_id g4f3c6 (9100/98693). 89593 posts left . . .
# Currently processing post_id g4kn0f (9150/98693). 89543 posts left . . .
# Currently processing post_id g4nozy (9200/98693). 89493 posts left . . .
# Currently processing post_id g4qnas (9250/98693). 89443 posts left . . .
# Currently processing post_id g4t7l9 (9300/98693). 89393 posts left . . .
# Currently processing post_id g4xcve (9350/98693). 89343 posts left . . .
# Currently processing post_id g537jn (9400/98693). 89293 posts left . . .
# Currently processing post_id g577mg (9450/98693). 89243 posts left . . .
# Currently processing post_id g5a9sa (9500/98693). 89193 posts left . . .
# Currently processing post_id g5cl3z (9550/98693). 89143 posts left . . .
# Currently processing post_id g5f4it (9600/98693). 89093 posts left . . .
# Currently processing post_id g5ip91 (9650/98693). 89043 posts left . . .
# Currently processing post_id g5mrp4 (9700/98693). 88993 posts left . . .
# Currently processing post_id g5qx6s (9750/98693). 88943 posts left . . .
# Currently processing post_id g5uvad (9800/98693). 88893 posts left . . .
# Currently processing post_id g5ybw3 (9850/98693). 88843 posts left . . .
# Currently processing post_id g61k21 (9900/98693). 88793 posts left . . .
# Currently processing post_id g65lvx (9950/98693). 88743 posts left . . .
# Currently processing post_id g69nik (10000/98693). 88693 posts left . . .
# Currently processing post_id g6dinl (10050/98693). 88643 posts left . . .
# Currently processing post_id g6hcqp (10100/98693). 88593 posts left . . .
# Currently processing post_id g6k3yq (10150/98693). 88543 posts left . . .
# Currently processing post_id g6m8ko (10200/98693). 88493 posts left . . .
# Currently processing post_id g6oh94 (10250/98693). 88443 posts left . . .
# Currently processing post_id g6rkwn (10300/98693). 88393 posts left . . .
# Currently processing post_id g6uvks (10350/98693). 88343 posts left . . .
# Currently processing post_id g6zj96 (10400/98693). 88293 posts left . . .
# Currently processing post_id g72cwg (10450/98693). 88243 posts left . . .
# Currently processing post_id g750as (10500/98693). 88193 posts left . . .
# Currently processing post_id g77dp5 (10550/98693). 88143 posts left . . .
# Currently processing post_id g7anck (10600/98693). 88093 posts left . . .
# Currently processing post_id g7dvpw (10650/98693). 88043 posts left . . .
# Currently processing post_id g7i93u (10700/98693). 87993 posts left . . .
# Currently processing post_id g7log9 (10750/98693). 87943 posts left . . .
# Currently processing post_id g7qlep (10800/98693). 87893 posts left . . .
# Currently processing post_id g7unhh (10850/98693). 87843 posts left . . .
# Currently processing post_id g7ygqi (10900/98693). 87793 posts left . . .
# Currently processing post_id g83klg (10950/98693). 87743 posts left . . .
# Currently processing post_id g88602 (11000/98693). 87693 posts left . . .
# Currently processing post_id g8bnv6 (11050/98693). 87643 posts left . . .
# Currently processing post_id g8f4vt (11100/98693). 87593 posts left . . .
# Currently processing post_id g8jpst (11150/98693). 87543 posts left . . .
# Currently processing post_id g8oxgw (11200/98693). 87493 posts left . . .
# Currently processing post_id g8tyi6 (11250/98693). 87443 posts left . . .
# Currently processing post_id g8xrvh (11300/98693). 87393 posts left . . .
# Currently processing post_id g90gkf (11350/98693). 87343 posts left . . .
# Currently processing post_id g946w5 (11400/98693). 87293 posts left . . .
# Currently processing post_id g98e46 (11450/98693). 87243 posts left . . .
# Currently processing post_id g9cp53 (11500/98693). 87193 posts left . . .
# Currently processing post_id g9gq3m (11550/98693). 87143 posts left . . .
# Currently processing post_id g9jdf8 (11600/98693). 87093 posts left . . .
# Currently processing post_id g9lhc7 (11650/98693). 87043 posts left . . .
# Currently processing post_id g9nzs8 (11700/98693). 86993 posts left . . .
# Currently processing post_id g9spwo (11750/98693). 86943 posts left . . .
# Currently processing post_id g9xbwq (11800/98693). 86893 posts left . . .
# Currently processing post_id ga1rnn (11850/98693). 86843 posts left . . .
# Currently processing post_id ga5pgg (11900/98693). 86793 posts left . . .
# Currently processing post_id ga9n8d (11950/98693). 86743 posts left . . .
# Currently processing post_id gae46m (12000/98693). 86693 posts left . . .
# Currently processing post_id gajhjo (12050/98693). 86643 posts left . . .
# Currently processing post_id gann34 (12100/98693). 86593 posts left . . .
# Currently processing post_id ptdxzb (12150/98693). 86543 posts left . . .
# Currently processing post_id pv6n8k (12200/98693). 86493 posts left . . .
# Currently processing post_id pxsnmo (12250/98693). 86443 posts left . . .
# Currently processing post_id pz7n0z (12300/98693). 86393 posts left . . .
# Currently processing post_id q13lny (12350/98693). 86343 posts left . . .
# Currently processing post_id q2tvxr (12400/98693). 86293 posts left . . .
# Currently processing post_id q4k8t9 (12450/98693). 86243 posts left . . .
# Currently processing post_id q6wg0b (12500/98693). 86193 posts left . . .
# Currently processing post_id q8cq7r (12550/98693). 86143 posts left . . .
# Currently processing post_id qa2dgb (12600/98693). 86093 posts left . . .
# Currently processing post_id qc02dl (12650/98693). 86043 posts left . . .
# Currently processing post_id gaqsyf (12700/98693). 85993 posts left . . .
# Currently processing post_id gatva7 (12750/98693). 85943 posts left . . .
# Currently processing post_id gax9qe (12800/98693). 85893 posts left . . .
# Currently processing post_id gb2ftm (12850/98693). 85843 posts left . . .
# Currently processing post_id gb6x6c (12900/98693). 85793 posts left . . .
# Currently processing post_id gbbngk (12950/98693). 85743 posts left . . .
# Currently processing post_id gbexwh (13000/98693). 85693 posts left . . .
# Currently processing post_id gbi42i (13050/98693). 85643 posts left . . .
# Currently processing post_id gbmnnc (13100/98693). 85593 posts left . . .
# Currently processing post_id gbpwop (13150/98693). 85543 posts left . . .
# Currently processing post_id gbzt4b (13200/98693). 85493 posts left . . .
# Currently processing post_id gc4dqk (13250/98693). 85443 posts left . . .
# Currently processing post_id gc909r (13300/98693). 85393 posts left . . .
# Currently processing post_id gcdrji (13350/98693). 85343 posts left . . .
# Currently processing post_id gcjwri (13400/98693). 85293 posts left . . .
# Currently processing post_id gcnjgh (13450/98693). 85243 posts left . . .
# Currently processing post_id gcqshv (13500/98693). 85193 posts left . . .
# Currently processing post_id gcwe4m (13550/98693). 85143 posts left . . .
# Currently processing post_id gd1vfh (13600/98693). 85093 posts left . . .
# Currently processing post_id gd5s0i (13650/98693). 85043 posts left . . .
# Currently processing post_id gd8zly (13700/98693). 84993 posts left . . .
# Currently processing post_id gdc1yp (13750/98693). 84943 posts left . . .
# Currently processing post_id gdgq64 (13800/98693). 84893 posts left . . .
# Currently processing post_id gdm7j5 (13850/98693). 84843 posts left . . .
# Currently processing post_id gdr3cc (13900/98693). 84793 posts left . . .
# Currently processing post_id gdu16i (13950/98693). 84743 posts left . . .
# Currently processing post_id gdwmiz (14000/98693). 84693 posts left . . .
# Currently processing post_id ge1eyh (14050/98693). 84643 posts left . . .
# Currently processing post_id ge5g83 (14100/98693). 84593 posts left . . .
# Currently processing post_id ge9ghd (14150/98693). 84543 posts left . . .
# Currently processing post_id geekob (14200/98693). 84493 posts left . . .
# Currently processing post_id gehtc9 (14250/98693). 84443 posts left . . .
# Currently processing post_id gel5o1 (14300/98693). 84393 posts left . . .
# Currently processing post_id ger0nx (14350/98693). 84343 posts left . . .
# Currently processing post_id gevueq (14400/98693). 84293 posts left . . .
# Currently processing post_id gezzsg (14450/98693). 84243 posts left . . .
# Currently processing post_id gf2xf2 (14500/98693). 84193 posts left . . .
# Currently processing post_id gf5lxl (14550/98693). 84143 posts left . . .
# Currently processing post_id gf9673 (14600/98693). 84093 posts left . . .
# Currently processing post_id gfd93h (14650/98693). 84043 posts left . . .
# Currently processing post_id gfk0ol (14700/98693). 83993 posts left . . .
# Currently processing post_id gfo2bv (14750/98693). 83943 posts left . . .
# Currently processing post_id gfqx98 (14800/98693). 83893 posts left . . .
# Currently processing post_id gfupfe (14850/98693). 83843 posts left . . .
# Currently processing post_id gfyv5t (14900/98693). 83793 posts left . . .
# Currently processing post_id gg4nau (14950/98693). 83743 posts left . . .
# Currently processing post_id gg7dab (15000/98693). 83693 posts left . . .
# Currently processing post_id ggarmh (15050/98693). 83643 posts left . . .
# Currently processing post_id gge8fq (15100/98693). 83593 posts left . . .
# Currently processing post_id ggixnq (15150/98693). 83543 posts left . . .
# Currently processing post_id ggnj8j (15200/98693). 83493 posts left . . .
# Currently processing post_id ggsn6l (15250/98693). 83443 posts left . . .
# Currently processing post_id ggxf8k (15300/98693). 83393 posts left . . .
# Currently processing post_id gh1vr1 (15350/98693). 83343 posts left . . .
# Currently processing post_id gh6vsf (15400/98693). 83293 posts left . . .
# Currently processing post_id ghcoov (15450/98693). 83243 posts left . . .
# Currently processing post_id ghgdjh (15500/98693). 83193 posts left . . .
# Currently processing post_id ghkh7d (15550/98693). 83143 posts left . . .
# Currently processing post_id ghpdkt (15600/98693). 83093 posts left . . .
# Currently processing post_id ghvbum (15650/98693). 83043 posts left . . .
# Currently processing post_id gi132g (15700/98693). 82993 posts left . . .
# Currently processing post_id gi5w74 (15750/98693). 82943 posts left . . .
# Currently processing post_id gia2zr (15800/98693). 82893 posts left . . .
# Currently processing post_id gigw4k (15850/98693). 82843 posts left . . .
# Currently processing post_id gimznk (15900/98693). 82793 posts left . . .
# Currently processing post_id gir6dq (15950/98693). 82743 posts left . . .
# Currently processing post_id giuzgq (16000/98693). 82693 posts left . . .
# Currently processing post_id gizxd6 (16050/98693). 82643 posts left . . .
# Currently processing post_id gj47ff (16100/98693). 82593 posts left . . .
# Currently processing post_id gj7sex (16150/98693). 82543 posts left . . .
# Currently processing post_id gjerfb (16200/98693). 82493 posts left . . .
# Currently processing post_id gjiqna (16250/98693). 82443 posts left . . .
# Currently processing post_id gjklsm (16300/98693). 82393 posts left . . .
# Currently processing post_id gjpj41 (16350/98693). 82343 posts left . . .
# Currently processing post_id gjv3uz (16400/98693). 82293 posts left . . .
# Currently processing post_id gk0ake (16450/98693). 82243 posts left . . .
# Currently processing post_id gk53z1 (16500/98693). 82193 posts left . . .
# Currently processing post_id gk8d94 (16550/98693). 82143 posts left . . .
# Currently processing post_id gkd2vj (16600/98693). 82093 posts left . . .
# Currently processing post_id gkhjlt (16650/98693). 82043 posts left . . .
# Currently processing post_id gkmhs9 (16700/98693). 81993 posts left . . .
# Currently processing post_id gkrfpk (16750/98693). 81943 posts left . . .
# Currently processing post_id gkviaa (16800/98693). 81893 posts left . . .
# Currently processing post_id gl36x0 (16850/98693). 81843 posts left . . .
# Currently processing post_id gl9fac (16900/98693). 81793 posts left . . .
# Currently processing post_id gleagq (16950/98693). 81743 posts left . . .
# Currently processing post_id glhxus (17000/98693). 81693 posts left . . .
# Currently processing post_id glo0d4 (17050/98693). 81643 posts left . . .
# Currently processing post_id gltv7l (17100/98693). 81593 posts left . . .
# Currently processing post_id glxxg9 (17150/98693). 81543 posts left . . .
# Currently processing post_id gm1yhx (17200/98693). 81493 posts left . . .
# Currently processing post_id gm7lk7 (17250/98693). 81443 posts left . . .
# Currently processing post_id gmb6pp (17300/98693). 81393 posts left . . .
# Currently processing post_id gmgg5p (17350/98693). 81343 posts left . . .
# Currently processing post_id gmk9bz (17400/98693). 81293 posts left . . .
# Currently processing post_id gmnkb2 (17450/98693). 81243 posts left . . .
# Currently processing post_id gmrgnq (17500/98693). 81193 posts left . . .
# Currently processing post_id gmumyy (17550/98693). 81143 posts left . . .
# Currently processing post_id gn1506 (17600/98693). 81093 posts left . . .
# Currently processing post_id gn5l8e (17650/98693). 81043 posts left . . .
# Currently processing post_id gn9zpo (17700/98693). 80993 posts left . . .
# Currently processing post_id gnez9p (17750/98693). 80943 posts left . . .
# Currently processing post_id gnia7z (17800/98693). 80893 posts left . . .
# Currently processing post_id gnk479 (17850/98693). 80843 posts left . . .
# Currently processing post_id gnnsb2 (17900/98693). 80793 posts left . . .
# Currently processing post_id gnsp3l (17950/98693). 80743 posts left . . .
# Currently processing post_id gnx6pq (18000/98693). 80693 posts left . . .
# Currently processing post_id go0suj (18050/98693). 80643 posts left . . .
# Currently processing post_id go6cg1 (18100/98693). 80593 posts left . . .
# Currently processing post_id goddzv (18150/98693). 80543 posts left . . .
# Currently processing post_id gohmw4 (18200/98693). 80493 posts left . . .
# Currently processing post_id gom4g5 (18250/98693). 80443 posts left . . .
# Currently processing post_id gophog (18300/98693). 80393 posts left . . .
# Currently processing post_id gosajc (18350/98693). 80343 posts left . . .
# Currently processing post_id goyp3p (18400/98693). 80293 posts left . . .
# Currently processing post_id gp3vmc (18450/98693). 80243 posts left . . .
# Currently processing post_id gpbjb6 (18500/98693). 80193 posts left . . .
# Currently processing post_id gphwbx (18550/98693). 80143 posts left . . .
# Currently processing post_id gplwgb (18600/98693). 80093 posts left . . .
# Currently processing post_id gpq3j4 (18650/98693). 80043 posts left . . .
# Currently processing post_id gpwvdr (18700/98693). 79993 posts left . . .
# Currently processing post_id gq5fi9 (18750/98693). 79943 posts left . . .
# Currently processing post_id gqagzc (18800/98693). 79893 posts left . . .
# Currently processing post_id gqform (18850/98693). 79843 posts left . . .
# Currently processing post_id gqjb4w (18900/98693). 79793 posts left . . .
# Currently processing post_id gqpb3u (18950/98693). 79743 posts left . . .
# Currently processing post_id gqul7e (19000/98693). 79693 posts left . . .
# Currently processing post_id gqztdh (19050/98693). 79643 posts left . . .
# Currently processing post_id gr4s45 (19100/98693). 79593 posts left . . .
# Currently processing post_id grcnct (19150/98693). 79543 posts left . . .
# Currently processing post_id grh4vc (19200/98693). 79493 posts left . . .
# Currently processing post_id grn1aj (19250/98693). 79443 posts left . . .
# Currently processing post_id grtcu3 (19300/98693). 79393 posts left . . .
# Currently processing post_id grzgts (19350/98693). 79343 posts left . . .
# Currently processing post_id gs3xiw (19400/98693). 79293 posts left . . .
# Currently processing post_id gs9gob (19450/98693). 79243 posts left . . .
# Currently processing post_id gsfaa9 (19500/98693). 79193 posts left . . .
# Currently processing post_id gskra7 (19550/98693). 79143 posts left . . .
# Currently processing post_id gsphpv (19600/98693). 79093 posts left . . .
# Currently processing post_id gstgsk (19650/98693). 79043 posts left . . .
# Currently processing post_id gszj1e (19700/98693). 78993 posts left . . .
# Currently processing post_id gt65k7 (19750/98693). 78943 posts left . . .
# Currently processing post_id gtcmb2 (19800/98693). 78893 posts left . . .
# Currently processing post_id gtj2b4 (19850/98693). 78843 posts left . . .
# Currently processing post_id gtqnam (19900/98693). 78793 posts left . . .
# Currently processing post_id gtxx9c (19950/98693). 78743 posts left . . .
# Currently processing post_id gu44up (20000/98693). 78693 posts left . . .
# Currently processing post_id gubvsr (20050/98693). 78643 posts left . . .
# Currently processing post_id gui2bp (20100/98693). 78593 posts left . . .
# Currently processing post_id gumt85 (20150/98693). 78543 posts left . . .
# Currently processing post_id gutpch (20200/98693). 78493 posts left . . .
# Currently processing post_id gv1mmv (20250/98693). 78443 posts left . . .
# Currently processing post_id gv59j1 (20300/98693). 78393 posts left . . .
# Currently processing post_id gv90rj (20350/98693). 78343 posts left . . .
# Currently processing post_id gvdrbe (20400/98693). 78293 posts left . . .
# Currently processing post_id gvmc8h (20450/98693). 78243 posts left . . .
# Currently processing post_id gvseb7 (20500/98693). 78193 posts left . . .
# Currently processing post_id gvyt3s (20550/98693). 78143 posts left . . .
# Currently processing post_id gw1hgi (20600/98693). 78093 posts left . . .
# Currently processing post_id gw7gh3 (20650/98693). 78043 posts left . . .
# Currently processing post_id gwb097 (20700/98693). 77993 posts left . . .
# Currently processing post_id gwgitj (20750/98693). 77943 posts left . . .
# Currently processing post_id gwmrod (20800/98693). 77893 posts left . . .
# Currently processing post_id gwq13g (20850/98693). 77843 posts left . . .
# Currently processing post_id gwwo1n (20900/98693). 77793 posts left . . .
# Currently processing post_id gx1zdu (20950/98693). 77743 posts left . . .
# Currently processing post_id gx7wmz (21000/98693). 77693 posts left . . .
# Currently processing post_id gxdih0 (21050/98693). 77643 posts left . . .
# Currently processing post_id gxgj76 (21100/98693). 77593 posts left . . .
# Currently processing post_id gxnu15 (21150/98693). 77543 posts left . . .
# Currently processing post_id gxvv1i (21200/98693). 77493 posts left . . .
# Currently processing post_id gy58s3 (21250/98693). 77443 posts left . . .
# Currently processing post_id gyc52g (21300/98693). 77393 posts left . . .
# Currently processing post_id gykt0u (21350/98693). 77343 posts left . . .
# Currently processing post_id gytnqk (21400/98693). 77293 posts left . . .
# Currently processing post_id gyyxcs (21450/98693). 77243 posts left . . .
# Currently processing post_id gz5pkr (21500/98693). 77193 posts left . . .
# Currently processing post_id gzc9yb (21550/98693). 77143 posts left . . .
# Currently processing post_id gziqsi (21600/98693). 77093 posts left . . .
# Currently processing post_id gzlth4 (21650/98693). 77043 posts left . . .
# Currently processing post_id gzrygx (21700/98693). 76993 posts left . . .
# Currently processing post_id h00zac (21750/98693). 76943 posts left . . .
# Currently processing post_id h07s75 (21800/98693). 76893 posts left . . .
# Currently processing post_id h0dnsp (21850/98693). 76843 posts left . . .
# Currently processing post_id h0nv7o (21900/98693). 76793 posts left . . .
# Currently processing post_id h0uddt (21950/98693). 76743 posts left . . .
# Currently processing post_id h0y078 (22000/98693). 76693 posts left . . .
# Currently processing post_id h11p5q (22050/98693). 76643 posts left . . .
# Currently processing post_id h186vi (22100/98693). 76593 posts left . . .
# Currently processing post_id h7at7k (22150/98693). 76543 posts left . . .
# Currently processing post_id h7fwhw (22200/98693). 76493 posts left . . .
# Currently processing post_id h7jh79 (22250/98693). 76443 posts left . . .
# Currently processing post_id h7pnac (22300/98693). 76393 posts left . . .
# Currently processing post_id h7ylzp (22350/98693). 76343 posts left . . .
# Currently processing post_id h83uk2 (22400/98693). 76293 posts left . . .
# Currently processing post_id h88s3a (22450/98693). 76243 posts left . . .
# Currently processing post_id h8dhyh (22500/98693). 76193 posts left . . .
# Currently processing post_id h8l8k1 (22550/98693). 76143 posts left . . .
# Currently processing post_id h8qztx (22600/98693). 76093 posts left . . .
# Currently processing post_id h8v0sd (22650/98693). 76043 posts left . . .
# Currently processing post_id h904mn (22700/98693). 75993 posts left . . .
# Currently processing post_id h98iqj (22750/98693). 75943 posts left . . .
# Currently processing post_id h9ed1a (22800/98693). 75893 posts left . . .
# Currently processing post_id h9jzgs (22850/98693). 75843 posts left . . .
# Currently processing post_id h9pgxw (22900/98693). 75793 posts left . . .
# Currently processing post_id h9ws6o (22950/98693). 75743 posts left . . .
# Currently processing post_id ha1utu (23000/98693). 75693 posts left . . .
# Currently processing post_id ha5asj (23050/98693). 75643 posts left . . .
# Currently processing post_id haa92f (23100/98693). 75593 posts left . . .
# Currently processing post_id hagt46 (23150/98693). 75543 posts left . . .
# Currently processing post_id hakzvm (23200/98693). 75493 posts left . . .
# Currently processing post_id haqmbe (23250/98693). 75443 posts left . . .
# Currently processing post_id hax4ld (23300/98693). 75393 posts left . . .
# Currently processing post_id hb54cz (23350/98693). 75343 posts left . . .
# Currently processing post_id hbbt6t (23400/98693). 75293 posts left . . .
# Currently processing post_id hbfg09 (23450/98693). 75243 posts left . . .
# Currently processing post_id hbm8d3 (23500/98693). 75193 posts left . . .
# Currently processing post_id hbtxpl (23550/98693). 75143 posts left . . .
# Currently processing post_id hc0khs (23600/98693). 75093 posts left . . .
# Currently processing post_id hc6d9r (23650/98693). 75043 posts left . . .
# Currently processing post_id hcdz9w (23700/98693). 74993 posts left . . .
# Currently processing post_id hcjokz (23750/98693). 74943 posts left . . .
# Currently processing post_id hcps3u (23800/98693). 74893 posts left . . .
# Currently processing post_id hcvrjn (23850/98693). 74843 posts left . . .
# Currently processing post_id hd31tr (23900/98693). 74793 posts left . . .
# Currently processing post_id hd8x0w (23950/98693). 74743 posts left . . .
# Currently processing post_id hdi5a1 (24000/98693). 74693 posts left . . .
# Currently processing post_id hdorg4 (24050/98693). 74643 posts left . . .
# Currently processing post_id hdtkju (24100/98693). 74593 posts left . . .
# Currently processing post_id he1ygh (24150/98693). 74543 posts left . . .
# Currently processing post_id he8miy (24200/98693). 74493 posts left . . .
# Currently processing post_id hecwry (24250/98693). 74443 posts left . . .
# Currently processing post_id hef0xr (24300/98693). 74393 posts left . . .
# Currently processing post_id hehldi (24350/98693). 74343 posts left . . .
# Currently processing post_id helwej (24400/98693). 74293 posts left . . .
# Currently processing post_id hetkga (24450/98693). 74243 posts left . . .
# Currently processing post_id hey9bs (24500/98693). 74193 posts left . . .
# Currently processing post_id hf279q (24550/98693). 74143 posts left . . .
# Currently processing post_id hf99w3 (24600/98693). 74093 posts left . . .
# Currently processing post_id hfewge (24650/98693). 74043 posts left . . .
# Currently processing post_id hfjc5l (24700/98693). 73993 posts left . . .
# Currently processing post_id hfn5dr (24750/98693). 73943 posts left . . .
# Currently processing post_id hfs61j (24800/98693). 73893 posts left . . .
# Currently processing post_id hfyo72 (24850/98693). 73843 posts left . . .
# Currently processing post_id hg3jpz (24900/98693). 73793 posts left . . .
# Currently processing post_id hg7dk2 (24950/98693). 73743 posts left . . .
# Currently processing post_id hgdhfv (25000/98693). 73693 posts left . . .
# Currently processing post_id hgjzah (25050/98693). 73643 posts left . . .
# Currently processing post_id hgnsy2 (25100/98693). 73593 posts left . . .
# Currently processing post_id hgti2s (25150/98693). 73543 posts left . . .
# Currently processing post_id hgzk6u (25200/98693). 73493 posts left . . .
# Currently processing post_id hh63f5 (25250/98693). 73443 posts left . . .
# Currently processing post_id hhb0oh (25300/98693). 73393 posts left . . .
# Currently processing post_id hhfm8n (25350/98693). 73343 posts left . . .
# Currently processing post_id hho1wp (25400/98693). 73293 posts left . . .
# Currently processing post_id hq30ur (25450/98693). 73243 posts left . . .
# Currently processing post_id hhw727 (25500/98693). 73193 posts left . . .
# Currently processing post_id hhzyc4 (25550/98693). 73143 posts left . . .
# Currently processing post_id hi68z8 (25600/98693). 73093 posts left . . .
# Currently processing post_id hibars (25650/98693). 73043 posts left . . .
# Currently processing post_id hifzf9 (25700/98693). 72993 posts left . . .
# Currently processing post_id hijen6 (25750/98693). 72943 posts left . . .
# Currently processing post_id hinoys (25800/98693). 72893 posts left . . .
# Currently processing post_id hitsdj (25850/98693). 72843 posts left . . .
# Currently processing post_id hiyneq (25900/98693). 72793 posts left . . .
# Currently processing post_id hj3a33 (25950/98693). 72743 posts left . . .
# Currently processing post_id hj7v2h (26000/98693). 72693 posts left . . .
# Currently processing post_id hjcx6t (26050/98693). 72643 posts left . . .
# Currently processing post_id hji4jk (26100/98693). 72593 posts left . . .
# Currently processing post_id hjmzpd (26150/98693). 72543 posts left . . .
# Currently processing post_id hjsih9 (26200/98693). 72493 posts left . . .
# Currently processing post_id hjwwio (26250/98693). 72443 posts left . . .
# Currently processing post_id hk23qo (26300/98693). 72393 posts left . . .
# Currently processing post_id hk4jjm (26350/98693). 72343 posts left . . .
# Currently processing post_id hk8e3s (26400/98693). 72293 posts left . . .
# Currently processing post_id hkbz1w (26450/98693). 72243 posts left . . .
# Currently processing post_id hkh4r6 (26500/98693). 72193 posts left . . .
# Currently processing post_id hkkhqr (26550/98693). 72143 posts left . . .
# Currently processing post_id hkphkp (26600/98693). 72093 posts left . . .
# Currently processing post_id hkuu1v (26650/98693). 72043 posts left . . .
# Currently processing post_id hkxi89 (26700/98693). 71993 posts left . . .
# Currently processing post_id hl0z40 (26750/98693). 71943 posts left . . .
# Currently processing post_id hl6qif (26800/98693). 71893 posts left . . .
# Currently processing post_id hlbk7s (26850/98693). 71843 posts left . . .
# Currently processing post_id hlg4x3 (26900/98693). 71793 posts left . . .
# Currently processing post_id hllacm (26950/98693). 71743 posts left . . .
# Currently processing post_id hlpn26 (27000/98693). 71693 posts left . . .
# Currently processing post_id hlvlyp (27050/98693). 71643 posts left . . .
# Currently processing post_id hlzein (27100/98693). 71593 posts left . . .
# Currently processing post_id hm2wco (27150/98693). 71543 posts left . . .
# Currently processing post_id hm60mk (27200/98693). 71493 posts left . . .
# Currently processing post_id hm9ic9 (27250/98693). 71443 posts left . . .
# Currently processing post_id hmee0g (27300/98693). 71393 posts left . . .
# Currently processing post_id hmji79 (27350/98693). 71343 posts left . . .
# Currently processing post_id hmnczv (27400/98693). 71293 posts left . . .
# Currently processing post_id hmqp2q (27450/98693). 71243 posts left . . .
# Currently processing post_id hmuac8 (27500/98693). 71193 posts left . . .
# Currently processing post_id hmwn7f (27550/98693). 71143 posts left . . .
# Currently processing post_id hmybky (27600/98693). 71093 posts left . . .
# Currently processing post_id hn17x4 (27650/98693). 71043 posts left . . .
# Currently processing post_id hn6jf1 (27700/98693). 70993 posts left . . .
# Currently processing post_id hnbl9b (27750/98693). 70943 posts left . . .
# Currently processing post_id hng3yi (27800/98693). 70893 posts left . . .
# Currently processing post_id hnl44t (27850/98693). 70843 posts left . . .
# Currently processing post_id hnqh5n (27900/98693). 70793 posts left . . .
# Currently processing post_id hnxcha (27950/98693). 70743 posts left . . .
# Currently processing post_id ho10jg (28000/98693). 70693 posts left . . .
# Currently processing post_id ho6byr (28050/98693). 70643 posts left . . .
# Currently processing post_id hobubg (28100/98693). 70593 posts left . . .
# Currently processing post_id hohp1f (28150/98693). 70543 posts left . . .
# Currently processing post_id homn0x (28200/98693). 70493 posts left . . .
# Currently processing post_id hoqtmw (28250/98693). 70443 posts left . . .
# Currently processing post_id hovjpz (28300/98693). 70393 posts left . . .
# Currently processing post_id hp1p1f (28350/98693). 70343 posts left . . .
# Currently processing post_id hp7hln (28400/98693). 70293 posts left . . .
# Currently processing post_id hpbj09 (28450/98693). 70243 posts left . . .
# Currently processing post_id hpghx4 (28500/98693). 70193 posts left . . .
# Currently processing post_id hpm635 (28550/98693). 70143 posts left . . .
# Currently processing post_id hppwcn (28600/98693). 70093 posts left . . .
# Currently processing post_id hptssd (28650/98693). 70043 posts left . . .
# Currently processing post_id hpyf6t (28700/98693). 69993 posts left . . .
# Currently processing post_id hq5v0e (28750/98693). 69943 posts left . . .
# Currently processing post_id hqac3l (28800/98693). 69893 posts left . . .
# Currently processing post_id hqekdv (28850/98693). 69843 posts left . . .
# Currently processing post_id hqj6qh (28900/98693). 69793 posts left . . .
# Currently processing post_id hqn97g (28950/98693). 69743 posts left . . .
# Currently processing post_id hqt1y4 (29000/98693). 69693 posts left . . .
# Currently processing post_id hqxelx (29050/98693). 69643 posts left . . .
# Currently processing post_id hqzy77 (29100/98693). 69593 posts left . . .
# Currently processing post_id hr4xvx (29150/98693). 69543 posts left . . .
# Currently processing post_id hrb76i (29200/98693). 69493 posts left . . .
# Currently processing post_id hrgv9l (29250/98693). 69443 posts left . . .
# Currently processing post_id hrlx9b (29300/98693). 69393 posts left . . .
# Currently processing post_id hrq4ap (29350/98693). 69343 posts left . . .
# Currently processing post_id hrufyh (29400/98693). 69293 posts left . . .
# Currently processing post_id hs0z13 (29450/98693). 69243 posts left . . .
# Currently processing post_id hs5uin (29500/98693). 69193 posts left . . .
# Currently processing post_id hsa1ik (29550/98693). 69143 posts left . . .
# Currently processing post_id hsd9ge (29600/98693). 69093 posts left . . .
# Currently processing post_id hsiszh (29650/98693). 69043 posts left . . .
# Currently processing post_id hsobzz (29700/98693). 68993 posts left . . .
# Currently processing post_id hstdd1 (29750/98693). 68943 posts left . . .
# Currently processing post_id hswg8e (29800/98693). 68893 posts left . . .
# Currently processing post_id ht09bj (29850/98693). 68843 posts left . . .
# Currently processing post_id ht6fpm (29900/98693). 68793 posts left . . .
# Currently processing post_id htcrq3 (29950/98693). 68743 posts left . . .
# Currently processing post_id htjidn (30000/98693). 68693 posts left . . .
# Currently processing post_id hto9l4 (30050/98693). 68643 posts left . . .
# Currently processing post_id httehf (30100/98693). 68593 posts left . . .
# Currently processing post_id htxwu5 (30150/98693). 68543 posts left . . .
# Currently processing post_id hu1hfy (30200/98693). 68493 posts left . . .
# Currently processing post_id hu7mho (30250/98693). 68443 posts left . . .
# Currently processing post_id hudr0k (30300/98693). 68393 posts left . . .
# Currently processing post_id huhzn6 (30350/98693). 68343 posts left . . .
# Currently processing post_id hukghj (30400/98693). 68293 posts left . . .
# Currently processing post_id hunm87 (30450/98693). 68243 posts left . . .
# Currently processing post_id hus28d (30500/98693). 68193 posts left . . .
# Currently processing post_id huydxt (30550/98693). 68143 posts left . . .
# Currently processing post_id hv1w2a (30600/98693). 68093 posts left . . .
# Currently processing post_id hv4y9t (30650/98693). 68043 posts left . . .
# Currently processing post_id hv8iq3 (30700/98693). 67993 posts left . . .
# Currently processing post_id hvdjmc (30750/98693). 67943 posts left . . .
# Currently processing post_id hvjztb (30800/98693). 67893 posts left . . .
# Currently processing post_id hvnnux (30850/98693). 67843 posts left . . .
# Currently processing post_id hvrgh5 (30900/98693). 67793 posts left . . .
# Currently processing post_id hvuc9u (30950/98693). 67743 posts left . . .
# Currently processing post_id hvznyy (31000/98693). 67693 posts left . . .
# Currently processing post_id hw6n7t (31050/98693). 67643 posts left . . .
# Currently processing post_id hwbs4q (31100/98693). 67593 posts left . . .
# Currently processing post_id hwecw6 (31150/98693). 67543 posts left . . .
# Currently processing post_id hwigkx (31200/98693). 67493 posts left . . .
# Currently processing post_id hwovza (31250/98693). 67443 posts left . . .
# Currently processing post_id hwur3p (31300/98693). 67393 posts left . . .
# Currently processing post_id hwzhhn (31350/98693). 67343 posts left . . .
# Currently processing post_id hx70jp (31400/98693). 67293 posts left . . .
# Currently processing post_id hxeomd (31450/98693). 67243 posts left . . .
# Currently processing post_id hxkbxw (31500/98693). 67193 posts left . . .
# Currently processing post_id hxo0yj (31550/98693). 67143 posts left . . .
# Currently processing post_id hxtxyf (31600/98693). 67093 posts left . . .
# Currently processing post_id hy0kkx (31650/98693). 67043 posts left . . .
# Currently processing post_id hy5bsp (31700/98693). 66993 posts left . . .
# Currently processing post_id hy9z1w (31750/98693). 66943 posts left . . .
# Currently processing post_id hyiw0f (31800/98693). 66893 posts left . . .
# Currently processing post_id hyo0g9 (31850/98693). 66843 posts left . . .
# Currently processing post_id hysbko (31900/98693). 66793 posts left . . .
# Currently processing post_id hyvnkt (31950/98693). 66743 posts left . . .
# Currently processing post_id hz0buy (32000/98693). 66693 posts left . . .
# Currently processing post_id hz6rqo (32050/98693). 66643 posts left . . .
# Currently processing post_id hzbafz (32100/98693). 66593 posts left . . .
# Currently processing post_id hzhke7 (32150/98693). 66543 posts left . . .
# Currently processing post_id hzmv14 (32200/98693). 66493 posts left . . .
# Currently processing post_id hzrzwl (32250/98693). 66443 posts left . . .
# Currently processing post_id hzwa0m (32300/98693). 66393 posts left . . .
# Currently processing post_id i0193i (32350/98693). 66343 posts left . . .
# Currently processing post_id i05gk8 (32400/98693). 66293 posts left . . .
# Currently processing post_id i0bh02 (32450/98693). 66243 posts left . . .
# Currently processing post_id i0gtqt (32500/98693). 66193 posts left . . .
# Currently processing post_id i0labr (32550/98693). 66143 posts left . . .
# ...
# Currently processing post_id knxews (87750/98693). 10943 posts left . . .
# Currently processing post_id ksm7je (87800/98693). 10893 posts left . . .
# Currently processing post_id kvz4pk (87850/98693). 10843 posts left . . .
# Currently processing post_id kzb6pp (87900/98693). 10793 posts left . . .
# Currently processing post_id l3kv5e (87950/98693). 10743 posts left . . .
# Currently processing post_id lh433t (88000/98693). 10693 posts left . . .
# Currently processing post_id lpzd99 (88050/98693). 10643 posts left . . .
# Currently processing post_id m3vp1j (88100/98693). 10593 posts left . . .
# Currently processing post_id mk6nej (88150/98693). 10543 posts left . . .
# Currently processing post_id msoe9e (88200/98693). 10493 posts left . . .
# Currently processing post_id n2r03u (88250/98693). 10443 posts left . . .
# Currently processing post_id nbo2kn (88300/98693). 10393 posts left . . .
# Currently processing post_id npn2j4 (88350/98693). 10343 posts left . . .
# Currently processing post_id o9s572 (88400/98693). 10293 posts left . . .
# Currently processing post_id ol2ehv (88450/98693). 10243 posts left . . .
# Currently processing post_id ordm2t (88500/98693). 10193 posts left . . .
# Currently processing post_id oyrud4 (88550/98693). 10143 posts left . . .
# Currently processing post_id p7i9lt (88600/98693). 10093 posts left . . .
# Currently processing post_id ph5j0z (88650/98693). 10043 posts left . . .
# Currently processing post_id ps0vrv (88700/98693). 9993 posts left . . .
# Currently processing post_id q55yre (88750/98693). 9943 posts left . . .
# Currently processing post_id ly44o1 (88800/98693). 9893 posts left . . .
# Currently processing post_id fi6jzp (88850/98693). 9843 posts left . . .
# Currently processing post_id fjzxu0 (88900/98693). 9793 posts left . . .
# Currently processing post_id fmfkfi (88950/98693). 9743 posts left . . .
# Currently processing post_id fpin2j (89000/98693). 9693 posts left . . .
# Currently processing post_id fsl84o (89050/98693). 9643 posts left . . .
# Currently processing post_id fvrixs (89100/98693). 9593 posts left . . .
# Currently processing post_id g0mwj0 (89150/98693). 9543 posts left . . .
# Currently processing post_id g5s1o9 (89200/98693). 9493 posts left . . .
# Currently processing post_id gbdbx2 (89250/98693). 9443 posts left . . .
# Currently processing post_id ggtkp7 (89300/98693). 9393 posts left . . .
# Currently processing post_id gn92se (89350/98693). 9343 posts left . . .
# Currently processing post_id gskpgc (89400/98693). 9293 posts left . . .
# Currently processing post_id gy4ppq (89450/98693). 9243 posts left . . .
# Currently processing post_id hblpdq (89500/98693). 9193 posts left . . .
# Currently processing post_id hfz1pu (89550/98693). 9143 posts left . . .
# Currently processing post_id hiy98x (89600/98693). 9093 posts left . . .
# Currently processing post_id hmwf5g (89650/98693). 9043 posts left . . .
# Currently processing post_id hqq4ah (89700/98693). 8993 posts left . . .
# Currently processing post_id huuhuk (89750/98693). 8943 posts left . . .
# Currently processing post_id hz7spz (89800/98693). 8893 posts left . . .
# Currently processing post_id i3ts5n (89850/98693). 8843 posts left . . .
# Currently processing post_id i9baez (89900/98693). 8793 posts left . . .
# Currently processing post_id iewpbq (89950/98693). 8743 posts left . . .
# Currently processing post_id ioa492 (90000/98693). 8693 posts left . . .
# Currently processing post_id izn33z (90050/98693). 8643 posts left . . .
# Currently processing post_id ja0di3 (90100/98693). 8593 posts left . . .
# Currently processing post_id jknbqj (90150/98693). 8543 posts left . . .
# Currently processing post_id jtwfe0 (90200/98693). 8493 posts left . . .
# Currently processing post_id jygthm (90250/98693). 8443 posts left . . .
# Currently processing post_id k49zae (90300/98693). 8393 posts left . . .
# Currently processing post_id k9f3b2 (90350/98693). 8343 posts left . . .
# Currently processing post_id kf9hep (90400/98693). 8293 posts left . . .
# Currently processing post_id kjewqd (90450/98693). 8243 posts left . . .
# Currently processing post_id ko1cmk (90500/98693). 8193 posts left . . .
# Currently processing post_id ku7gdw (90550/98693). 8143 posts left . . .
# Currently processing post_id kzqfz7 (90600/98693). 8093 posts left . . .
# Currently processing post_id l8e3dm (90650/98693). 8043 posts left . . .
# Currently processing post_id lkfq0v (90700/98693). 7993 posts left . . .
# Currently processing post_id lwhyux (90750/98693). 7943 posts left . . .
# Currently processing post_id m3mzk1 (90800/98693). 7893 posts left . . .
# Currently processing post_id mhytyp (90850/98693). 7843 posts left . . .
# Currently processing post_id mr0fju (90900/98693). 7793 posts left . . .
# Currently processing post_id n0jcx4 (90950/98693). 7743 posts left . . .
# Currently processing post_id ngnyg8 (91000/98693). 7693 posts left . . .
# Currently processing post_id nz3gqt (91050/98693). 7643 posts left . . .
# Currently processing post_id ogmmxb (91100/98693). 7593 posts left . . .
# Currently processing post_id otnqvf (91150/98693). 7543 posts left . . .
# Currently processing post_id p42hw0 (91200/98693). 7493 posts left . . .
# Currently processing post_id pfzm6h (91250/98693). 7443 posts left . . .
# Currently processing post_id pyosce (91300/98693). 7393 posts left . . .
# Currently processing post_id lino44 (91350/98693). 7343 posts left . . .
# Currently processing post_id fgm6xo (91400/98693). 7293 posts left . . .
# Currently processing post_id fjw7mm (91450/98693). 7243 posts left . . .
# Currently processing post_id fm1ugz (91500/98693). 7193 posts left . . .
# Currently processing post_id fpjlxw (91550/98693). 7143 posts left . . .
# Currently processing post_id fuhhml (91600/98693). 7093 posts left . . .
# Currently processing post_id fyqetz (91650/98693). 7043 posts left . . .
# Currently processing post_id g464vj (91700/98693). 6993 posts left . . .
# Currently processing post_id gc4w6n (91750/98693). 6943 posts left . . .
# Currently processing post_id gkt3yw (91800/98693). 6893 posts left . . .
# Currently processing post_id gsx2l2 (91850/98693). 6843 posts left . . .
# Currently processing post_id hb2bh6 (91900/98693). 6793 posts left . . .
# Currently processing post_id hn3wlj (91950/98693). 6743 posts left . . .
# Currently processing post_id hv6cej (92000/98693). 6693 posts left . . .
# Currently processing post_id i0zj04 (92050/98693). 6643 posts left . . .
# Currently processing post_id ia93g5 (92100/98693). 6593 posts left . . .
# Currently processing post_id ijs2xm (92150/98693). 6543 posts left . . .
# Currently processing post_id iwc66w (92200/98693). 6493 posts left . . .
# Currently processing post_id jchscz (92250/98693). 6443 posts left . . .
# Currently processing post_id jst0ag (92300/98693). 6393 posts left . . .
# Currently processing post_id jyj4iw (92350/98693). 6343 posts left . . .
# Currently processing post_id k7fhqv (92400/98693). 6293 posts left . . .
# Currently processing post_id kfq4cr (92450/98693). 6243 posts left . . .
# Currently processing post_id knvgrp (92500/98693). 6193 posts left . . .
# Currently processing post_id kwtio2 (92550/98693). 6143 posts left . . .
# Currently processing post_id l951co (92600/98693). 6093 posts left . . .
# Currently processing post_id lo9u7h (92650/98693). 6043 posts left . . .
# Currently processing post_id m4t7dd (92700/98693). 5993 posts left . . .
# Currently processing post_id ml1db4 (92750/98693). 5943 posts left . . .
# Currently processing post_id mvywpe (92800/98693). 5893 posts left . . .
# Currently processing post_id n5mmfv (92850/98693). 5843 posts left . . .
# Currently processing post_id nj5hvu (92900/98693). 5793 posts left . . .
# Currently processing post_id nymm4k (92950/98693). 5743 posts left . . .
# Currently processing post_id oagi9e (93000/98693). 5693 posts left . . .
# Currently processing post_id om8cj2 (93050/98693). 5643 posts left . . .
# Currently processing post_id ou37do (93100/98693). 5593 posts left . . .
# Currently processing post_id p1mwjm (93150/98693). 5543 posts left . . .
# Currently processing post_id pbg6q6 (93200/98693). 5493 posts left . . .
# Currently processing post_id plisfc (93250/98693). 5443 posts left . . .
# Currently processing post_id pwjtgv (93300/98693). 5393 posts left . . .
# Currently processing post_id q8tgkd (93350/98693). 5343 posts left . . .
# Currently processing post_id fhqxh3 (93400/98693). 5293 posts left . . .
# Currently processing post_id fo9sdj (93450/98693). 5243 posts left . . .
# Currently processing post_id fxeglq (93500/98693). 5193 posts left . . .
# Currently processing post_id gdnymh (93550/98693). 5143 posts left . . .
# Currently processing post_id gwkx40 (93600/98693). 5093 posts left . . .
# Currently processing post_id hnpezh (93650/98693). 5043 posts left . . .
# Currently processing post_id i0t8ol (93700/98693). 4993 posts left . . .
# Currently processing post_id ildc65 (93750/98693). 4943 posts left . . .
# Currently processing post_id jgl862 (93800/98693). 4893 posts left . . .
# Currently processing post_id jyeiod (93850/98693). 4843 posts left . . .
# Currently processing post_id kixup8 (93900/98693). 4793 posts left . . .
# Currently processing post_id l6es1f (93950/98693). 4743 posts left . . .
# Currently processing post_id mgljiw (94000/98693). 4693 posts left . . .
# Currently processing post_id n2ydhq (94050/98693). 4643 posts left . . .
# Currently processing post_id o2vapp (94100/98693). 4593 posts left . . .
# Currently processing post_id oylljl (94150/98693). 4543 posts left . . .
# Currently processing post_id fcomr1 (94200/98693). 4493 posts left . . .
# Currently processing post_id ftvpow (94250/98693). 4443 posts left . . .
# Currently processing post_id gghcak (94300/98693). 4393 posts left . . .
# Currently processing post_id hsgtgl (94350/98693). 4343 posts left . . .
# Currently processing post_id j22xcj (94400/98693). 4293 posts left . . .
# Currently processing post_id k7bbjc (94450/98693). 4243 posts left . . .
# Currently processing post_id lxtx8x (94500/98693). 4193 posts left . . .
# Currently processing post_id p694st (94550/98693). 4143 posts left . . .
# Currently processing post_id qbbem5 (94600/98693). 4093 posts left . . .
# Currently processing post_id fj3cqd (94650/98693). 4043 posts left . . .
# Currently processing post_id fmfpvd (94700/98693). 3993 posts left . . .
# Currently processing post_id fpuc3v (94750/98693). 3943 posts left . . .
# Currently processing post_id fuesc6 (94800/98693). 3893 posts left . . .
# Currently processing post_id fyex4i (94850/98693). 3843 posts left . . .
# Currently processing post_id g77joo (94900/98693). 3793 posts left . . .
# Currently processing post_id ggk58l (94950/98693). 3743 posts left . . .
# Currently processing post_id gowk5p (95000/98693). 3693 posts left . . .
# Currently processing post_id hb6a2n (95050/98693). 3643 posts left . . .
# Currently processing post_id hm6if4 (95100/98693). 3593 posts left . . .
# Currently processing post_id hwjje5 (95150/98693). 3543 posts left . . .
# Currently processing post_id i7mlyb (95200/98693). 3493 posts left . . .
# Currently processing post_id j13sd6 (95250/98693). 3443 posts left . . .
# Currently processing post_id jkc696 (95300/98693). 3393 posts left . . .
# Currently processing post_id jw75to (95350/98693). 3343 posts left . . .
# Currently processing post_id k2t7z4 (95400/98693). 3293 posts left . . .
# Currently processing post_id kcl2th (95450/98693). 3243 posts left . . .
# Currently processing post_id kqfydl (95500/98693). 3193 posts left . . .
# Currently processing post_id lai3i3 (95550/98693). 3143 posts left . . .
# Currently processing post_id m3uzyw (95600/98693). 3093 posts left . . .
# Currently processing post_id na360g (95650/98693). 3043 posts left . . .
# Currently processing post_id o7qesy (95700/98693). 2993 posts left . . .
# Currently processing post_id p2eavi (95750/98693). 2943 posts left . . .
# Currently processing post_id pfru3f (95800/98693). 2893 posts left . . .
# Currently processing post_id q5e7ug (95850/98693). 2843 posts left . . .
# Currently processing post_id ffg4m2 (95900/98693). 2793 posts left . . .
# Currently processing post_id fikyt6 (95950/98693). 2743 posts left . . .
# Currently processing post_id fldd8j (96000/98693). 2693 posts left . . .
# Currently processing post_id foc8j2 (96050/98693). 2643 posts left . . .
# Currently processing post_id fqv7if (96100/98693). 2593 posts left . . .
# Currently processing post_id ft7s8o (96150/98693). 2543 posts left . . .
# Currently processing post_id fw7ji8 (96200/98693). 2493 posts left . . .
# Currently processing post_id fzyxkl (96250/98693). 2443 posts left . . .
# Currently processing post_id g3hjpv (96300/98693). 2393 posts left . . .
# Currently processing post_id g7c1ju (96350/98693). 2343 posts left . . .
# Currently processing post_id gbjfl7 (96400/98693). 2293 posts left . . .
# Currently processing post_id ghmbou (96450/98693). 2243 posts left . . .
# Currently processing post_id gmuekx (96500/98693). 2193 posts left . . .
# Currently processing post_id gtm6cv (96550/98693). 2143 posts left . . .
# Currently processing post_id h9qm4w (96600/98693). 2093 posts left . . .
# Currently processing post_id hd1i2i (96650/98693). 2043 posts left . . .
# Currently processing post_id hg6s7j (96700/98693). 1993 posts left . . .
# Currently processing post_id hhpe6d (96750/98693). 1943 posts left . . .
# Currently processing post_id hk9mxd (96800/98693). 1893 posts left . . .
# Currently processing post_id hmwguq (96850/98693). 1843 posts left . . .
# Currently processing post_id hoxrvf (96900/98693). 1793 posts left . . .
# Currently processing post_id hr88gi (96950/98693). 1743 posts left . . .
# Currently processing post_id ht3lpd (97000/98693). 1693 posts left . . .
# Currently processing post_id hx23pg (97050/98693). 1643 posts left . . .
# Currently processing post_id i18q3o (97100/98693). 1593 posts left . . .
# Currently processing post_id ia1l37 (97150/98693). 1543 posts left . . .
# Currently processing post_id ii7tln (97200/98693). 1493 posts left . . .
# Currently processing post_id izll3j (97250/98693). 1443 posts left . . .
# Currently processing post_id jcyz96 (97300/98693). 1393 posts left . . .
# Currently processing post_id jrm8e5 (97350/98693). 1343 posts left . . .
# Currently processing post_id k1kvuq (97400/98693). 1293 posts left . . .
# Currently processing post_id k92ewn (97450/98693). 1243 posts left . . .
# Currently processing post_id kghexa (97500/98693). 1193 posts left . . .
# Currently processing post_id kqhva4 (97550/98693). 1143 posts left . . .
# Currently processing post_id l02llx (97600/98693). 1093 posts left . . .
# Currently processing post_id lgckad (97650/98693). 1043 posts left . . .
# Currently processing post_id lphq7o (97700/98693). 993 posts left . . .
# Currently processing post_id m4zvwz (97750/98693). 943 posts left . . .
# Currently processing post_id ms1jj4 (97800/98693). 893 posts left . . .
# Currently processing post_id nbs94e (97850/98693). 843 posts left . . .
# Currently processing post_id oace7l (97900/98693). 793 posts left . . .
# Currently processing post_id otk9zb (97950/98693). 743 posts left . . .
# Currently processing post_id oxs80d (98000/98693). 693 posts left . . .
# Currently processing post_id p0mxd4 (98050/98693). 643 posts left . . .
# Currently processing post_id p3mzi6 (98100/98693). 593 posts left . . .
# Currently processing post_id p8crgg (98150/98693). 543 posts left . . .
# Currently processing post_id pgd2zm (98200/98693). 493 posts left . . .
# Currently processing post_id pqzoyx (98250/98693). 443 posts left . . .
# Currently processing post_id qc2d02 (98300/98693). 393 posts left . . .
# Currently processing post_id fl1vip (98350/98693). 343 posts left . . .
# Currently processing post_id gfvn33 (98400/98693). 293 posts left . . .
# Currently processing post_id hrqp3t (98450/98693). 243 posts left . . .
# Currently processing post_id j5d20n (98500/98693). 193 posts left . . .
# Currently processing post_id kftmz0 (98550/98693). 143 posts left . . .
# Currently processing post_id lm9ppv (98600/98693). 93 posts left . . .
# Currently processing post_id nw8ltk (98650/98693). 43 posts left . . .

# %%
# Experimenting with the groupby functions

data = pd.read_csv("C:/Users/Andre/Documents/DBL/Reaching Understanding Study/no_t_data.csv", encoding_errors= 'replace')
groups = data.groupby(['submission_link_id'], sort = False)
groups.transform(processing_posts)

# %%
# Troubleshooting posts that cause the code to error out

processing_for_coding_troubleshooting(data, "k87ecd")

# %% [markdown]
# + Next PyClub after thanksgiving
#     + Thanks Connor!!
#     + What do we want to hand-label (covid data?)
#     + Make a codebook for how we code things
#         + Identify disagreement and agreement
#         + Label our actual predictors/outcomes
#         + We'll probably use both NLP and hand-labeling
#             + Hand label the outcome (do they reach agreement?)
#             + Use NLP to measure predictors
#     + We have example data for what we'll be coding
#         + Develop a codebook - what constructs do we want to measure manually and what do we want to measure with automated text analysis
#         + We have lots of conversations on covid, do we want any other issues as well?
#
# + Code Book Ideas (measure perceived understanding)
#     + Label for agree/disagree based on the first comment
#         + Strength of disagreement/agreement; 5-point scale
#     + Do they seem to accurately understand the other persons views?
#     + How well do they seem to understand what the other person believes?
#     + How well do they seem to understand the other persons values?
#     + How well do they seem to understand what the other person is saying?
#     + Measure based on only what they are saying, not what you think they understand deep down
